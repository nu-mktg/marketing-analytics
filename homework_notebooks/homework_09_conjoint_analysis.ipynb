# %% [markdown]
# # Homework 9: Conjoint Analysis
# ### Marketing Analytics
# **Collaboration:** Part A = individual. B & C = permitted.

# %% [markdown]
# ---
# ## Part A: Math Questions
#
# Logit model output:
# - β_price = -0.15 (per $1 increase)
# - β_premium_content = +1.10 (vs standard)
# - β_no_ads = +1.80 (vs ads)
# - β_annual_plan = +0.60 (vs monthly)

# %%
# Q1. WTP for premium content = beta_premium / |beta_price|
q1_wtp_premium = None
print(f'Q1 WTP premium: ${q1_wtp_premium}')

# %%
# Q2. WTP to go from ads to no-ads = beta_no_ads / |beta_price|
q2_wtp_no_ads = None
print(f'Q2 WTP no-ads: ${q2_wtp_no_ads}')

# %%
# Q3. Which attribute has the highest WTP? Enter 'premium_content',
# 'no_ads', or 'annual_plan'
q3_highest_wtp = None
print(f'Q3 highest WTP: {q3_highest_wtp}')

# %%
# Q4. Two products:
# Product X: standard, ads, $10/month → utility_X = 0 + 0 + (-0.15*10)
# Product Y: premium, no ads, $16/month → utility_Y = 1.10 + 1.80 + (-0.15*16)
# Compute both utilities.
import math
q4_utility_x = None
q4_utility_y = None
print(f'Q4 utility X: {q4_utility_x}, utility Y: {q4_utility_y}')

# %%
# Q5. Market share for X under logit softmax:
# share_X = exp(U_X) / (exp(U_X) + exp(U_Y))
# Round to 3dp.
q5_share_x = None
print(f'Q5 share X: {q5_share_x}')

# %%
# Q6. Market share for Y under logit softmax. Round to 3dp.
q6_share_y = None
print(f'Q6 share Y: {q6_share_y}')

# %%
# Q7. True or False: WTP from conjoint represents the MAXIMUM a customer
# will pay — not a guarantee that all customers pay that amount.
q7_wtp_interpretation = None
print(f'Q7: {q7_wtp_interpretation}')

# %%
# Q8. IIA property: if a new Product Z identical to X but at $9 is introduced,
# how does it affect the X:Y market share ratio?
# a) X:Y ratio stays the same (IIA — draw proportionally from both)
# b) X loses all its share to Z
# c) Y gains share because Z is introduced
# d) X:Y ratio doubles
q8_iia = None
print(f'Q8: {q8_iia}')

# %% [markdown]
# ---
# ## Part B: Agent
# ### Collaboration permitted
#
# ### Context Prompt:
#
# ```
# Dataset: conjoint_survey.csv
# Columns: respondent_id, task_id, chosen (0/1),
#   price (10,14,18,22), content (standard/premium),
#   ads (full_ads/limited_ads/no_ads), plan (monthly/annual)
#
# Please:
# 1. Fit a multinomial logit (MNL) model using statsmodels or pylogit:
#    chosen ~ price + C(content) + C(ads) + C(plan)
# 2. Print: all coefficients with standard errors, p-values.
# 3. Compute WTP for: premium_content, no_ads (vs full_ads), annual_plan.
# 4. Market simulation: compute market shares for these 3 products:
#    A: standard, full_ads, monthly, $12
#    B: premium, no_ads, monthly, $18
#    C: standard, limited_ads, annual, $15
# 5. Interpret attribute importance (rank by |coefficient|).
# Use seed=42.
# ```

# %%
# Q9. Coefficient on price (beta_price). Round to 3dp.
q9_beta_price = None
print(f'Q9 beta_price: {q9_beta_price}')

# %%
# Q10. WTP for premium_content ($). Round to 2dp.
q10_wtp_premium = None
print(f'Q10 WTP premium: ${q10_wtp_premium}')

# %%
# Q11. Market share for Product B (premium, no_ads, $18). Round to 1dp.
q11_share_b = None
print(f'Q11 share B: {q11_share_b}%')

# %%
# Q12. Rank attributes by importance (highest |coef| first). Enter as list,
# e.g. ['no_ads','premium_content','annual_plan','price']
q12_attribute_rank = None
print(f'Q12 rank: {q12_attribute_rank}')

# %% [markdown]
# ---
# ## Part C: Interpretation

# %%
# Q13. WTP for no_ads = $12. Current ad-supported tier costs $10.
# Premium (no ads) tier should be priced at:
# a) Exactly $22 (current price + WTP)
# b) Somewhere between $10 and $22, informed by WTP but adjusted for demand
# c) Exactly $12 more than ad-supported for every customer
# d) Based only on competitor pricing
q13 = None
print(f'Q13: {q13}')

# %%
# Q14. The IIA assumption means adding a new premium product at $20 would:
# a) Only draw share from other premium products
# b) Draw share from all existing products proportional to their current shares
# c) Not affect market shares
# d) Double the share of the cheapest product
q14 = None
print(f'Q14: {q14}')

# %%
# Q15. Attribute importance ranking shows 'no_ads' has the highest |coefficient|.
# A product manager concludes 'We should make all tiers ad-free.'
# What critical information does WTP analysis add to this decision?
# a) Nothing — high importance confirms ad-free is the right choice
# b) WTP quantifies how much revenue the ad-free feature justifies;
#    removing ads from all tiers has a cost that must be weighed
# c) WTP analysis is irrelevant for product decisions
# d) The PM should only look at the lowest-WTP attribute
q15 = None
print(f'Q15: {q15}')

# %% [markdown]
# ---
# ## Answer Summary

# %%
answers={
    "q1_wtp_premium":q1_wtp_premium,
    "q2_wtp_no_ads":q2_wtp_no_ads,
    "q3_highest_wtp":q3_highest_wtp,
    "q4_utility_x":q4_utility_x,
    "q4_utility_y":q4_utility_y,
    "q5_share_x":q5_share_x,
    "q6_share_y":q6_share_y,
    "q7_wtp_interpretation":q7_wtp_interpretation,
    "q8_iia":q8_iia,
    "q9_beta_price":q9_beta_price,
    "q10_wtp_premium":q10_wtp_premium,
    "q11_share_b":q11_share_b,
    "q12_attribute_rank":q12_attribute_rank,
    "q13":q13,
    "q14":q14,
    "q15":q15,
}
unanswered=[k for k,v in answers.items() if v is None]
print('⚠️',unanswered) if unanswered else print('✅ Ready.')
[print(f'  {k}: {v}') for k,v in answers.items()]
