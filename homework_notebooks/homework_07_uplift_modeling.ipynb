# %% [markdown]
# # Homework 7: Uplift Modeling
# ### Part A individual. Parts B and C collaborative.
#
# **Dataset:** `uplift_experiment.csv` — 4,000 customers, randomized experiment.
# Columns: `customer_id, treated (0/1), converted (0/1), tenure_months, avg_workouts_week, streak_active, support_tickets_30d, plan_type`

# %%
print("uplift_experiment.csv: 4000 customers, 50/50 random treatment/control")
print("treatment=1: received $5 coupon. converted=1: purchased within 14 days")

# %% [markdown]
# ## Part A: Math
# ### Individual

# %%
# These values are fixed for this homework — do not change them
N_TREATED = 2000
CONV_TREATED = 340
N_CONTROL = 2000
CONV_CONTROL = 260
COST = 5           # campaign cost per customer
AOV = 60           # average order value
GIVEN_TAU = 0.06   # a customer's predicted uplift, for Q5

print(f"Treated: {CONV_TREATED}/{N_TREATED}, Control: {CONV_CONTROL}/{N_CONTROL}")
print(f"Cost: ${COST}, AOV: ${AOV}, GIVEN_TAU: {GIVEN_TAU}")

# %%
# Q1. Treated group: N_TREATED customers, CONV_TREATED conversions (defined above).
# Compute treated conversion rate.
q1_treated_rate = None
print(f'Q1: {q1_treated_rate:.4f}')

# %%
# Q2. Control group: N_CONTROL customers, CONV_CONTROL conversions (defined above).
# Compute control conversion rate.
q2_control_rate = None
print(f'Q2: {q2_control_rate:.4f}')

# %%
# Q3. Compute the Average Treatment Effect (ATE) = treated_rate - control_rate
q3_ate = None
print(f'Q3 ATE: {q3_ate:.4f}')

# %%
# Q4. Campaign cost = COST per customer. Average order value = AOV (defined above).
# Minimum profitable uplift threshold = COST / AOV
q4_min_threshold = None
print(f'Q4 min threshold: {q4_min_threshold:.4f}')

# %%
# Q5. True or False:
# A customer with predicted uplift tau_hat = GIVEN_TAU should be targeted,
# given the COST and AOV defined above (compare GIVEN_TAU to your Q4 threshold).
q5_target_decision = None
print(f'Q5: {q5_target_decision}')

# %%
# Q6. True or False:
# The T-learner requires that treatment was randomly assigned.
# If customers self-selected into treatment, estimates are biased.
q6_randomization_required = None
print(f'Q6: {q6_randomization_required}')

# %%
# Q7. A customer segment has mean predicted uplift tau_hat = -0.04.
# This segment is called what in uplift modeling terminology?
# Enter: 'sure_things', 'lost_causes', 'persuadables', or 'sleeping_dogs'
q7_segment_name = None
print(f'Q7: {q7_segment_name}')

# %%
# Q8. True or False:
# A higher Qini coefficient means the model is better at
# ranking customers by their predicted uplift.
q8_qini_meaning = None
print(f'Q8: {q8_qini_meaning}')

# %% [markdown]
# ## Part B: Agent
# ### Collaboration permitted
#
# ```
# I am building an uplift model using a randomized experiment.
#
# uplift_experiment.csv has: customer_id, treated (0/1), converted (0/1),
# tenure_months, avg_workouts_week, streak_active, support_tickets_30d, plan_type.
# 50/50 random assignment. treatment=1 means $5 coupon received.
#
# Please:
# 1. Verify treatment balance: compare treated vs control means on all features.
# 2. Fit a T-learner using Random Forest (n_estimators=100, random_state=42):
#    - mu1: train on treated customers only
#    - mu0: train on control customers only
#    - tau_hat = mu1(X) - mu0(X) for all customers
# 3. Report: ATE, mean tau_hat on test set, and the Qini coefficient computed with
#    sklift.metrics.qini_auc_score (the scikit-uplift implementation pinned in
#    requirements.txt). Qini has several incompatible definitions, so use that one.
#    Compute the Qini ON THE HELD-OUT TEST SET (the 20%), scoring it with the models
#    trained on the 80% -- NOT in-sample. Qini is a RANKING metric, so unlike the
#    means above it is not robust to this choice: in-sample it comes out about 20x
#    larger, because the forests have memorised the training rows.
# 4. Plot the Qini curve.
# 5. Report: what % of customers have tau_hat < 0 (sleeping dogs)?
# 6. Given $5 cost and $60 AOV (this scenario's own figures — deliberately fixed
#    for everyone, and not the personalized constants from Part A), what % of
#    customers should be targeted
#    (tau_hat > threshold)?
# Use 80/20 train/test split, seed=42 -- specifically
# train_test_split(X, y, treated, test_size=0.2, random_state=42) with NO stratify
# argument. Do not stratify: the test-set Qini is very sensitive to which rows land in
# the test set (stratify=y moves it from 0.018 to 0.038), so the exact split call is
# part of the specification.
# ```

# %%
# q9_mean_tau
# Mean predicted uplift tau_hat on test set. Round to 3 decimal places.
q9_mean_tau = None
print(f'q9_mean_tau: {q9_mean_tau}')

# %%
# q10_qini
# Qini coefficient. Round to 2 decimal places.
q10_qini = None
print(f'q10_qini: {q10_qini}')

# %%
# q11_pct_sleeping
# % of customers with tau_hat < 0 (sleeping dogs). Round to 1 decimal.
q11_pct_sleeping = None
print(f'q11_pct_sleeping: {q11_pct_sleeping}')

# %%
# q12_pct_target
# % of customers with tau_hat > 0.083. Round to 1 decimal.
# Use 0.083 — it is THIS scenario's threshold ($5 cost / $60 AOV, stated in the
# Part B brief above), NOT your personalized Part A q4_min_threshold.
q12_pct_target = None
print(f'q12_pct_target: {q12_pct_target}')

# %%
# q13_top_feature_t
# Top feature importance in mu1 (treatment model). Enter feature name.
q13_top_feature_t = None
print(f'q13_top_feature_t: {q13_top_feature_t}')

# %% [markdown]
# ## Part C: Interpretation

# %%
# Q14. Suppose an uplift study reports mean tau_hat = 0.039 against an
# observed ATE of 0.040. (Illustrative numbers — not this homework's own
# q9/Q3 results.) This gap:
# a) Is expected — sampling variation in T-learner estimation
# b) Proves a coding error
# c) Means the model is biased
# d) Should be exactly zero for a valid model
q14 = None
print(f'Q14: {q14}')

# %%
# Q15. Suppose 8% of a campaign's audience are sleeping dogs.
# (Illustrative — not this homework's own q11 result.)
# Practically, targeting them:
# a) Wastes $5 but does no harm otherwise
# b) Should be ignored — 8% is too small to matter
# c) May prompt them to question whether they want the product, increasing churn
# d) Increases the overall ATE
q15 = None
print(f'Q15: {q15}')

# %%
# Q16. The balanced treatment check (Q feature comparison) matters because:
# a) It confirms the model will generalize to new data
# b) It validates the randomization — imbalanced features suggest
#    treatment assignment was not truly random
# c) It ensures the Qini coefficient is above 0.3
# d) It is only relevant for neural network models
q16 = None
print(f'Q16: {q16}')

# %% [markdown]
# ## Answer Summary

# %%
answers = {
    "q1_treated_rate": q1_treated_rate,
    "q2_control_rate": q2_control_rate,
    "q3_ate": q3_ate,
    "q4_min_threshold": q4_min_threshold,
    "q5_target_decision": q5_target_decision,
    "q6_randomization_required": q6_randomization_required,
    "q7_segment_name": q7_segment_name,
    "q8_qini_meaning": q8_qini_meaning,
    "q9_mean_tau": q9_mean_tau,
    "q10_qini": q10_qini,
    "q11_pct_sleeping": q11_pct_sleeping,
    "q12_pct_target": q12_pct_target,
    "q13_top_feature_t": q13_top_feature_t,
    "q14": q14,
    "q15": q15,
    "q16": q16,
}
unanswered=[k for k,v in answers.items() if v is None]
if unanswered:
    print(f'⚠️  Still None: {unanswered}')
else:
    print('✅ Ready to submit.')
for k,v in answers.items():
    print(f'  {k}: {v}')
