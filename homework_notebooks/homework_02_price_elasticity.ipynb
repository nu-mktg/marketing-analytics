# %% [markdown]
# # Homework 2: Price Elasticity of Demand
# ### Marketing Analytics — Submit via GitHub Classroom
#
# **Due:** Start of the following week's lecture
# **Collaboration policy:** Part A must be completed individually. Parts B and C may be completed collaboratively.

# %%
print("Dataset: pricing_data.csv loaded in your Codespace")
print("Columns: week, store_id, product_id, units_sold, price, competitor_price, display_flag")

# %% [markdown]
# ---
# ## Part A: Math Questions
# ### Complete individually
#
# Replace each `None` with your computed value. Show arithmetic in comments.

# %%
# Q1. Dataset: prices [5,6,7,8,9], units [200,160,140,110,90]
# Compute the mean price (x-bar)
q1_mean_price = None
print(f'Q1: {q1_mean_price}')

# %%
# Q2. Compute the mean units sold (y-bar)
q2_mean_units = None
print(f'Q2: {q2_mean_units}')

# %%
# Q3. Compute sum((xi - x_bar)(yi - y_bar))
# Build a table of deviations as in the worked example
q3_cov_numerator = None
print(f'Q3: {q3_cov_numerator}')

# %%
# Q4. Compute sum((xi - x_bar)^2)
q4_var_denominator = None
print(f'Q4: {q4_var_denominator}')

# %%
# Q5. Compute OLS slope beta_1 = Q3 / Q4
q5_beta1 = None
print(f'Q5 beta1: {q5_beta1}')

# %%
# Q6. Compute OLS intercept beta_0 = y_bar - beta_1 * x_bar
q6_beta0 = None
print(f'Q6 beta0: {q6_beta0}')

# %%
# Q7. Predicted units when price = $7.50
# y_hat = beta_0 + beta_1 * 7.50
q7_prediction = None
print(f'Q7 prediction: {q7_prediction}')

# %%
# Q8. In log-log model, which variable is the predictor (x)?
# Enter "log_price" or "log_units"
q8_log_predictor = None
print(f'Q8: {q8_log_predictor}')

# %%
# Q9. With elasticity = -1.4, a 1% price increase causes what % change in units?
# Enter as a number (e.g., -2.3 for a 2.3% decrease)
q9_pct_change = None
print(f'Q9: {q9_pct_change}%')

# %%
# Q10. Is elasticity of -1.4 elastic or inelastic?
# Enter "elastic" or "inelastic"
q10_elastic_or_not = None
print(f'Q10: {q10_elastic_or_not}')

# %%
# Q11. With elasticity -1.4, if price rises 5%, what happens to revenue?
# Enter "increases", "decreases", or "stays_the_same"
q11_revenue_effect = None
print(f'Q11: {q11_revenue_effect}')

# %% [markdown]
# ---
# ## Part B: Agent Questions
# ### Collaboration permitted
#
# Paste the context prompt below into your agent, then record the outputs.
#
# ---
#
# ### Context Prompt:
#
# ```
# I am a pricing analyst estimating price elasticity.
# The file pricing_data.csv contains: week, store_id, product_id,
# units_sold, price, competitor_price, display_flag.
#
# Please:
# 1. Create log-transformed variables: log_units, log_price, log_comp_price
# 2. Fit a log-log OLS regression using statsmodels:
#    log_units ~ log_price + log_comp_price + display_flag
#    with store and product fixed effects (use C(store_id) + C(product_id))
# 3. Print the full regression summary table
# 4. State the own-price elasticity and cross-price elasticity
# Use random seed 42.
# ```

# %%
# Q12. Own-price elasticity coefficient (log_price). Round to 2 decimal places.
q12_own_price_elasticity = None
print(f'Q12: {q12_own_price_elasticity}')

# %%
# Q13. Is own-price elasticity statistically significant (p < 0.05)? True/False
q13_significant = None
print(f'Q13: {q13_significant}')

# %%
# Q14. Cross-price elasticity coefficient (log_comp_price). Round to 2 decimal places.
q14_cross_price_elasticity = None
print(f'Q14: {q14_cross_price_elasticity}')

# %%
# Q15. R-squared of the regression. Round to 2 decimal places.
q15_r_squared = None
print(f'Q15 R²: {q15_r_squared}')

# %% [markdown]
# ---
# ## Part C: Interpretation Questions
# ### Collaboration permitted
#
# Enter `"a"`, `"b"`, `"c"`, or `"d"`

# %%
# Q16. Positive cross-price elasticity means the two products are:
# a) Complements — competitor price rise reduces our sales
# b) Substitutes — competitor price rise shifts demand to us
# c) Unrelated
# d) Identical
q16 = None
print(f'Q16: {q16}')

# %%
# Q17. "Our regression proves raising price causes sales to drop." Correct?
# a) Yes — negative coefficient proves causation
# b) No — regression shows correlation; endogeneity may bias the estimate
# c) No — regression cannot detect any relationship
# d) Yes — because R² is high
q17 = None
print(f'Q17: {q17}')

# %% [markdown]
# ---
# ## Answer Summary — Run before submitting

# %%
answers = {
    "q1_mean_price": q1_mean_price,
    "q2_mean_units": q2_mean_units,
    "q3_cov_numerator": q3_cov_numerator,
    "q4_var_denominator": q4_var_denominator,
    "q5_beta1": q5_beta1,
    "q6_beta0": q6_beta0,
    "q7_prediction": q7_prediction,
    "q8_log_predictor": q8_log_predictor,
    "q9_pct_change": q9_pct_change,
    "q10_elastic_or_not": q10_elastic_or_not,
    "q11_revenue_effect": q11_revenue_effect,
    "q12_own_price_elasticity": q12_own_price_elasticity,
    "q13_significant": q13_significant,
    "q14_cross_price_elasticity": q14_cross_price_elasticity,
    "q15_r_squared": q15_r_squared,
    "q16": q16,
    "q17": q17,
}

unanswered = [k for k,v in answers.items() if v is None]
if unanswered:
    print(f"⚠️  Still None: {unanswered}")
else:
    print("✅  All answered. Ready to submit.")

for k,v in answers.items():
    print(f"  {k}: {v}")
