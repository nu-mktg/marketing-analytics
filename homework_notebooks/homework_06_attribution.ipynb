# %% [markdown]
# # Homework 6: Multi-Touch Attribution
# ### Marketing Analytics
# **Collaboration:** Part A = individual. B & C = permitted.

# %% [markdown]
# ---
# ## Part A: Math Questions
#
# 3-channel setup: Paid Search (PS), Social (S), Email (E). Overall conversion rate = 0.48.
#
# Shapley values provided: φ_PS=0.22, φ_S=0.18, φ_E=0.08. Last-touch: PS=12%, S=25%, E=63%.

# %%
# Q1. Sum of the three Shapley values. What does this equal?
q1_shapley_sum = None
print(f'Q1 sum: {q1_shapley_sum}')

# %%
# Q2. Under last-touch, Email gets 63% of credit. Under Shapley, Email gets
# 0.08/0.48 = what % of Shapley-allocated conversion credit? Round to 1dp.
q2_email_shapley_pct = None
print(f'Q2 Email Shapley %: {q2_email_shapley_pct}%')

# %%
# Q3. How many orderings exist for 3 channels? (n! with n=3)
q3_orderings = None
print(f'Q3 orderings: {q3_orderings}')

# %%
# Q4. True or False: In Shapley attribution, Paid Search receiving higher credit
# than last-touch implies Paid Search should get a larger budget.
q4_shapley_budget = None
print(f'Q4: {q4_shapley_budget}')

# %%
# Q5. Markov removal effect for Email = 0.12. This means:
# removing Email reduces conversion probability by what percentage points?
q5_removal_effect = None
print(f'Q5: {q5_removal_effect}pp')

# %%
# Q6. True or False: Shapley attribution satisfies the efficiency axiom,
# meaning values sum to v({all channels}) = overall conversion rate.
q6_efficiency = None
print(f'Q6: {q6_efficiency}')

# %%
# Q7. Last-touch gives Email 63% but Shapley gives 17% (=0.08/0.48).
# What does this divergence most likely indicate?
# a) Email is the most important channel
# b) Email frequently closes paths it did not create
# c) The Shapley model has a bug
# d) Email spend should be tripled
q7_divergence = None
print(f'Q7: {q7_divergence}')

# %%
# Q8. With 4 channels, how many orderings must be enumerated for Shapley?
q8_four_channel_orderings = None
print(f'Q8: {q8_four_channel_orderings}')

# %% [markdown]
# ---
# ## Part B: Agent
# ### Collaboration permitted
#
# ### Context Prompt:
#
# ```
# Dataset: attribution_data.csv
# Columns: conversion_id, path (list of channels), converted (0/1)
# Channels: Paid_Search, Social, Email, Display
#
# Please:
# 1. Compute last-touch attribution: fraction of conversions where each
#    channel was the final touchpoint.
# 2. Compute Shapley attribution by enumerating all channel orderings.
#    For each ordering, compute marginal contribution of each channel.
#    Average across orderings.
# 3. Compute Markov chain removal effects: for each channel, set its
#    transition probability to zero and measure conversion rate drop.
# 4. Print a comparison table: Last-touch %, Shapley value,
#    Shapley %, Markov removal effect for each channel.
# 5. Plot a grouped bar chart comparing all three methods.
# Use seed=42.
# ```

# %%
# Q9. Last-touch % for Paid_Search. Round to 1dp.
q9_lt_paid_search = None
print(f'Q9 LT Paid Search: {q9_lt_paid_search}%')

# %%
# Q10. Shapley value for Paid_Search. Round to 3dp.
q10_shapley_ps = None
print(f'Q10 Shapley PS: {q10_shapley_ps}')

# %%
# Q11. Markov removal effect for Display. Round to 3dp.
q11_removal_display = None
print(f'Q11 Removal Display: {q11_removal_display}')

# %%
# Q12. Which channel has the largest divergence between last-touch % and Shapley %?
q12_biggest_divergence = None
print(f'Q12: {q12_biggest_divergence}')

# %% [markdown]
# ---
# ## Part C: Interpretation

# %%
# Q13. Shapley attribution requires no randomized experiment — True/False?
q13 = None
print(f'Q13: {q13}')

# %%
# Q14. A channel with Shapley value near zero but high last-touch credit:
# a) Should have its budget cut immediately
# b) Likely captures demand created by other channels rather than creating it
# c) Is unmeasurable and should be excluded
# d) Should have its budget doubled
q14 = None
print(f'Q14: {q14}')

# %%
# Q15. Shapley attribution vs incrementality holdout tests:
# a) They always give the same result
# b) Shapley measures marginal contribution within observed paths;
#    holdouts measure true causal incrementality
# c) Holdouts are less reliable than Shapley
# d) They answer exactly the same question
q15 = None
print(f'Q15: {q15}')

# %% [markdown]
# ---
# ## Answer Summary

# %%
answers={
    "q1_shapley_sum":q1_shapley_sum,
    "q2_email_shapley_pct":q2_email_shapley_pct,
    "q3_orderings":q3_orderings,
    "q4_shapley_budget":q4_shapley_budget,
    "q5_removal_effect":q5_removal_effect,
    "q6_efficiency":q6_efficiency,
    "q7_divergence":q7_divergence,
    "q8_four_channel_orderings":q8_four_channel_orderings,
    "q9_lt_paid_search":q9_lt_paid_search,
    "q10_shapley_ps":q10_shapley_ps,
    "q11_removal_display":q11_removal_display,
    "q12_biggest_divergence":q12_biggest_divergence,
    "q13":q13,
    "q14":q14,
    "q15":q15,
}
unanswered=[k for k,v in answers.items() if v is None]
print('⚠️',unanswered) if unanswered else print('✅ Ready.')
[print(f'  {k}: {v}') for k,v in answers.items()]
