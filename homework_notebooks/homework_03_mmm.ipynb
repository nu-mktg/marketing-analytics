# %% [markdown]
# # Homework 3: Marketing Mix Modeling
# ### Marketing Analytics — Submit via GitHub Classroom
#
# **Due:** Start of the following week's lecture
# **Collaboration policy:** Part A must be completed individually. Parts B and C may be completed collaboratively.

# %%
print("Dataset: mmm_data.csv loaded")
print("Columns: week, tv_spend, digital_spend, social_spend, revenue")

# %% [markdown]
# ---
# ## Part A: Math Questions
# ### Complete individually
#
# Replace each `None` with your computed value. Show arithmetic in comments.

# %%
# Q1. Spend sequence: S1=200, S2=100, S3=0, S4=150. Lambda=0.7
# Compute A1 = S1 + lambda*A0, where A0=0
q1_adstock_1 = None
print(f'Q1 A1: {q1_adstock_1}')

# %%
# Q2. Compute A2 = S2 + lambda*A1
q2_adstock_2 = None
print(f'Q2 A2: {q2_adstock_2}')

# %%
# Q3. Compute A3 = S3 + lambda*A2
q3_adstock_3 = None
print(f'Q3 A3: {q3_adstock_3}')

# %%
# Q4. Compute A4 = S4 + lambda*A3
q4_adstock_4 = None
print(f'Q4 A4: {q4_adstock_4}')

# %%
# Q5. Hill function: EC50=200, alpha=2. Compute H(200).
# H(s) = s^alpha / (EC50^alpha + s^alpha)
q5_hill_ec50 = None
print(f'Q5 H(EC50): {q5_hill_ec50}')

# %%
# Q6. Compute H(100) with EC50=200, alpha=2. Round to 4 decimal places.
q6_hill_100 = None
print(f'Q6 H(100): {q6_hill_100}')

# %%
# Q7. Compute H(400) with EC50=200, alpha=2. Round to 4 decimal places.
q7_hill_400 = None
print(f'Q7 H(400): {q7_hill_400}')

# %%
# Q8. H(200)-H(100) = 0.5 - 0.2 = ? (shows diminishing returns)
q8_marginal_gain = None
print(f'Q8 marginal gain: {q8_marginal_gain}')

# %%
# Q9. True or False: lambda=0.9 gives higher week-3 adstock than
# lambda=0.3, given only S1=100 and no other spend.
q9_decay_comparison = None
print(f'Q9: {q9_decay_comparison}')

# %%
# Q10. Channel A marginal ROI=$4. Channel B marginal ROI=$1.50.
# Move $1,000 from B to A: what is net revenue gain?
q10_revenue_gain = None
print(f'Q10 revenue gain: ${q10_revenue_gain}')

# %% [markdown]
# ---
# ## Part B: Agent Questions
# ### Collaboration permitted
#
# Paste the context prompt below into your agent, then record the outputs.
#
# ---
#
# ### Context Prompt:
#
# ```
# I am building a Marketing Mix Model.
# mmm_data.csv has columns: week, tv_spend, digital_spend, social_spend, revenue
# (all spend and revenue in $000s, 104 weeks).
#
# Build an MMM:
# 1. Adstock: A_t = S_t + lambda*A_{t-1}, A_0=0. Fit separate lambda per channel.
# 2. Hill function: H(A; EC50, alpha) = A^alpha / (EC50^alpha + A^alpha). Fit per channel.
# 3. Regression: Revenue_t = beta_0 + beta_TV*H(A_TV) + beta_Digital*H(A_Digital)
#    + beta_Social*H(A_Social) + error
# 4. Budget optimization: find allocation of current average total weekly budget
#    that maximizes predicted weekly revenue.
# Use scipy.optimize with seed=42. Print fitted lambda, EC50, alpha per channel,
# beta coefficients, and predicted revenue uplift (%) from optimal reallocation.
# ```

# %%
# Q11. Fitted decay parameter (lambda) for TV. Round to 2 decimal places.
q11_lambda_tv = None
print(f'Q11 lambda_TV: {q11_lambda_tv}')

# %%
# Q12. Fitted EC50 for Digital ($000s). Round to 1 decimal place.
q12_ec50_digital = None
print(f'Q12 EC50_Digital: {q12_ec50_digital}')

# %%
# Q13. Should TV spend increase or decrease from current?
# Enter "increase" or "decrease"
q13_tv_direction = None
print(f'Q13: {q13_tv_direction}')

# %%
# Q14. Predicted revenue uplift (%) from optimal reallocation. Round to 1 decimal place.
q14_revenue_uplift = None
print(f'Q14 uplift: {q14_revenue_uplift}%')

# %% [markdown]
# ---
# ## Part C: Interpretation Questions
# ### Collaboration permitted
#
# Enter `"a"`, `"b"`, `"c"`, or `"d"`

# %%
# Q15. Hill response H=0.82 for TV means:
# a) TV spend is well below EC50 — high marginal return
# b) TV spend is at exactly EC50
# c) TV spend is well above EC50 — diminishing returns have set in
# d) Cannot determine without knowing actual spend
q15 = None
print(f'Q15: {q15}')

# %%
# Q16. True or False: lambda=0 means advertising has no effect on sales
q16 = None
print(f'Q16: {q16}')

# %%
# Q17. Budget optimization recommends tripling Social and cutting TV to zero.
# Most important check before acting:
# a) Whether TV lambda > Social lambda
# b) Whether predicted revenue at current spend matches actual revenue
# c) Whether EC50 for Social < EC50 for TV
# d) Whether beta_Social > beta_TV
q17 = None
print(f'Q17: {q17}')

# %% [markdown]
# ---
# ## Answer Summary — Run before submitting

# %%
answers = {
    "q1_adstock_1": q1_adstock_1,
    "q2_adstock_2": q2_adstock_2,
    "q3_adstock_3": q3_adstock_3,
    "q4_adstock_4": q4_adstock_4,
    "q5_hill_ec50": q5_hill_ec50,
    "q6_hill_100": q6_hill_100,
    "q7_hill_400": q7_hill_400,
    "q8_marginal_gain": q8_marginal_gain,
    "q9_decay_comparison": q9_decay_comparison,
    "q10_realloc_to": q10_realloc_to,
    "q11_lambda_tv": q11_lambda_tv,
    "q12_ec50_digital": q12_ec50_digital,
    "q13_tv_direction": q13_tv_direction,
    "q14_revenue_uplift": q14_revenue_uplift,
    "q15": q15,
    "q16": q16,
    "q17": q17,
}

unanswered = [k for k,v in answers.items() if v is None]
if unanswered:
    print(f"⚠️  Still None: {unanswered}")
else:
    print("✅  All answered. Ready to submit.")

for k,v in answers.items():
    print(f"  {k}: {v}")
